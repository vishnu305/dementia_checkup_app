# %% [markdown]
# # WELCOME TO THE SECOND LAYER OF ALZHEIMER'S IDENTIFICATION

# %% [markdown]
# # SUBSEQUENT RECALL TEST

# %%
from IPython.display import Image
Image(filename='aa.jpg',width=500)
print("Hello Patient,Welcome To the Virtual Dementia Detection System")
print("I am Virtual Doctor")
print("Could you tell me your name and age so that I could finalize your reports at the end of all subsequent tests\n"
      )
name = input("Enter your name:")
age = int(input("Enter your age:"))
print(
    f"OK {name} Firstly I would like to inform you regarding the tests that we conduct for diagnosis of Dementia are as follows:\n")
print("\t 1.Subsequent Recall Test\n"
      "\t 2.Time Orientation Test\n "
      "\t 3.Personal Information Test\n "
      "\t 4.Rememberance Test\n"
      "\t 5.Comaprsion Test\n "
      "\t 6.Memory Test\n",
      "\t 7.Image Recognition Test")
print("So now let's start with our first test i.e.Subsequent Recall Test\n")
print(
    "I am giving you a Name and Address you have to remember it. After few minutes I will ask you to tell it again. It's clear.\n")
print("Here is the Name and Address: \n")
new_name = "Lucky Sehwag"
new_street = "Indira Nagar"
new_city = "Lucknow"
print(new_name, new_street, new_city)
print("Your time starts now!!")
# import the time module
import time


# define the countdown func.
def countdown(t):
    while t:
        mins, secs = divmod(t, 60)
        timer = '{:02d}:{:02d}'.format(mins, secs)
        print(timer, end="\r")
        time.sleep(1)
        t -= 1


# input time in seconds
t = input("Enter the time in seconds: ")
print("Your Time starts!!")

# function call
countdown(int(t))
  
print("Your time finishes!!")
print(
    "Are you able to recall the name and address which I have given you few minutes earlier. Please respond by writing it")
print("Please enter Name followed by Address")
countforD=0
countForND=0
countForSD=0 
response = input("Enter Name, location and city:")
print(response)
count67=0

if(response=='Lucky Sehwag'or response=='Indira Nagar' or response== 'Lucknow'):
    count67=1
    print('Your Score is:',count67)
elif(response=='Lucky Sehwag Indira Nagar 'or response=='Indira Nagar Lucknow' or response=='Lucky Sehwag Lucknow'):
    count67=2
    print('Your Score is:',count67)
elif(response=='Lucky Sehwag Indira Nagar Lucknow '):
    count67=3
    print('Your Score is:',count67)
 
if(count67==1):
    countforD=countforD+1
    print("You are suffering from  Dementia")
elif(count67==2):
    countForSD=countForSD+1
    print("You have just started showing symptoms of Dementia")
elif(count67==3):
     countForND=countForND+1
     print("You are not having Dementia")
    
countforD1=countforD
countForSD1=countForSD
countForND1=countForND
# Out:
# Hello Patient,Welcome To the Virtual Dementia Detection System
# I am Virtual Doctor
# Could you tell me your name and age so that I could finalize your reports at the end of all subsequent tests
#
# Enter your name:RAVI KUMAR GUPTA
# Enter your age:18
# OK RAVI KUMAR GUPTA Firstly I would like to inform you regarding the tests that we conduct for diagnosis of Dementia are as follows:
#
# 	 1.Subsequent Recall Test
# 	 2.Time Orientation Test
#  	 3.Personal Information Test
#  	 4.Rememberance Test
# 	 5.Comaprsion Test
#  	 6.Memory Test
#  	 7.Image Recognition Test
# So now let's start with our first test i.e.Subsequent Recall Test
#
# I am giving you a Name and Address you have to remember it. After few minutes I will ask you to tell it again. It's clear.
#
# Here is the Name and Address:
#
# Lucky Sehwag Indira Nagar Lucknow
# Your time starts now!!
# Enter the time in seconds: 3
# Your Time starts!!
# Your time finishes!!
# ...

# %% [markdown]
# # TIME ORIENTATION TEST

# %%
print("Welcome Once Again!! Now we will move to the next Test which is Time Orientation Test")
print("Basically In this test you have to tell me the todays date :")

Year=int(input("Enter the Year:"))
Month=int(input("Enter the Month:"))
Day=int(input("Enter the Day:"))
# Import date class from datetime module

import datetime 
    
# using now() to get current time 
current_time = datetime.datetime.now() 
    
# Printing attributes of now(). 
print ("The correct Date of today is : ") 
    
print ("Year : ", end = "") 
y=current_time.year
print(y) 
    
print ("Month : ", end = "") 
m=current_time.month
print (m) 
    
print ("Day : ", end = "") 
d=current_time.day
print (d) 
e='Your Score: 2'
a='Your Score: 1'
b='Your Score: 0'
count=0
count1=0
count2=0


if(Year==y and Month==m and Day==d):
    count=e
    print(e)

elif(Year==y or Year!=y and Month==m or Month!=m and Day==d or Day!=d):
    count1=a
    print(a)
else: 
    count2=b
    print(b)
           
if(count2==b):
    print('You have Dementia')
    countforD1=countforD1+1
elif(count1==a):
    print('You are on the verge of developing symptoms')
    countForSD1=countForSD1 + 1
elif(count==e):
    print('You are not having Dementia')
    countForND1=countForND1 + 1
    
countforD2=countforD1
countForND2=countForND1
countForSD2=countForSD1
# Out:
# Welcome Once Again!! Now we will move to the next Test which is Time Orientation Test
# Basically In this test you have to tell me the todays date :
# Enter the Year:2021
# Enter the Month:10
# Enter the Day:8
# The correct Date of today is :
# Year : 2021
# Month : 10
# Day : 8
# Your Score: 2
# You are not having Dementia

# %% [markdown]
# # PERSONAL INFORMATION TEST

# %%
print('Welcome To the Next Test! We will begin this test now.Let me tell you that in this test you have to tell me the answers in Yes/No format and In the end we will be able to reach the final score')
      
# import the time module
import time

# define the countdown func.
def countdown(t):
    while t:
        mins, secs = divmod(t, 60)
        timer = '{:02d}:{:02d}'.format(mins, secs)
        print(timer, end="\r")
        time.sleep(1)
        t -= 1


# input time in seconds
t = input("Enter the time in seconds: ")
print("Your Time starts!!")


# function call
countdown(int(t))
print("Your time finishes!!")
print('Now start with the questions')
print('Do you forget information that you have learned recently')

response=input("Please Enter Your Response: ")
count85=0
if(response=='Yes'or response=='yes' or response=='YES'):
      count85=1+count85
      print('Your Score: ',count85)

else:
      count85=0+count85
      print('Your Score: ',count85)
count86=count85
print('Do you have to ask for the same information again or need reminder notes?')
response1=input("Please Enter Your Response:")
if(response1=='Yes'or response1=='yes' or response1=='YES'):
      count86=1+count86
      print('Your Score: ',count86)

else:
      count86=0+count86
      print('Your Score: ',count86)
count87=count86
print('Do you have trouble following instructions, like a recipe or directions?')
      
response2=input('Please Enter Your Response: ')
if(response2=='Yes'or response=='yes' or response2=='YES'):
      count87=1+count87
      print('Your Score: ',count87)

else:
      count87=0+count87
      print('Your Score: ',count87)
count88=count87

print('Do you struggle to keep track of finances or pay bills on time?')      
response3=input('Please Enter Your Response: ')
if(response3=='Yes'or response3=='yes' or response3=='YES'):
      count88=1+count88
      print('Your Score: ',count88)

else:
      count88=0+count88
      print('Your Score: ',count88)
count89=count88
print('Do you experience visual problems, such as trouble with reading or judging distance or color?')                
response4=input('Please Enter Your Response: ')
if(response4=='Yes'or response4=='yes' or response4=='YES'):
      count89=1+count89
      print('Your Score: ',count89)

else:
     count89=0+count89
     print('Your Score: ',count89)
count90=count89
print('Have you or others noticed changes in your personality, such as becoming easily upset or anxious?')
response5=input('Please Enter Your Response: ')
if(response5=='Yes'or response5=='yes' or response5=='YES'):
      count90=1+count90
      print('Your Score: ',count89)

else:
     count90=0+count90
     print('Your Score: ',count89)


if(count90>4):
    print('You are not having Dementia')
    countForND2=countForND2 + 1

elif (count90>=2 and count90<=4 ):
    print('You have just started showing symptoms of Dementia')
    countForSD2=countForSD2 + 1
else:
  
    print('You have symptoms of Dementia')
    countforD2=countforD2+ 1
    
    

countforD3=countforD2 
countForSD3=countForSD2
countForND3=countForND2
# Out:
# Welcome To the Next Test! We will begin this test now.Let me tell you that in this test you have to tell me the answers in Yes/No format and In the end we will be able to reach the final score
# Enter the time in seconds: 1
# Your Time starts!!
# Your time finishes!!
# Now start with the questions
# Do you forget information that you have learned recently
# Please Enter Your Response: Yes
# Your Score:  1
# Do you have to ask for the same information again or need reminder notes?
# Please Enter Your Response:No
# Your Score:  1
# Do you have trouble following instructions, like a recipe or directions?
# Please Enter Your Response: No
# Your Score:  1
# Do you struggle to keep track of finances or pay bills on time?
# Please Enter Your Response: Yes
# Your Score:  2
# Do you experience visual problems, such as trouble with reading or judging distance or color?
# Please Enter Your Response: Yes
# Your Score:  3
# ...

# %% [markdown]
# # REMEMBERANCE TEST

# %%
print("Welcome Once Again!!Now we will move to the most crucial test  which is the Rememberance Test")
print("You have to tell me Name,Location and City which have been asked from you during the First test.")
response=input('Enter your response:')
count67=0
if(response=='Lucky Sehwag'or response=='Indira Nagar' or response== 'Lucknow'):
    count67=1
    print('Your Score is:',count67)
elif(response=='Lucky Sehwag Indira Nagar 'or response=='Indira Nagar Lucknow' or response=='Lucky Sehwag Lucknow'):
    count67=2
    print('Your Score is:',count67)
elif(response=='Lucky Sehwag Indira Nagar Lucknow '):
    count67=3
    print('Your Score is:',count67)

if(count67==1):
    print("You are suffering from  Dementia")
    countforD3=countforD3 + 1
elif(count67==2):
    print("You have just started showing symptoms of Dementia")
    countForSD3=countForSD3 + 1
elif(count67==3):
    print("You are not having Dementia ")
    countForND3=countForND3 + 1
    
countforD4=countforD3
countForSD4=countForSD3
countForND4=countForND3
# Out:
# Welcome Once Again!!Now we will move to the most crucial test  which is the Rememberance Test
# You have to tell me Name,Location and City which have been asked from you during the First test.
# Enter your response:Lucky Sehwag
# Your Score is: 1
# You are suffering from  Dementia

# %% [markdown]
# # COMPARISION TEST

# %%
print("Welcome Once Again!!We will move to the Comaparision Test.In this test, patient answers for previous tests are compared to when he was well suppose 5-6 years ago. The scores are given for every question and final score is calculated on the basis of total score of all questions:  ")
print('Please wait for sometime and relax')
# import the time module
import time

# define the countdown func.
def countdown(t):
    while t:
        mins, secs = divmod(t, 60)
        timer = '{:02d}:{:02d}'.format(mins, secs)
        print(timer, end="\r")
        time.sleep(1)
        t -= 1


# input time in seconds
t = input("Enter the time in seconds: ")
print("Your Time starts!!")


# function call
countdown(int(t))
print("Your time finishes!!")
print('Questioning starts')
print('Do you have difficulty in understanding recent  things than what it used to be 5-6 years ago')

response=input('Enter your response: ')
count13=0
if(response==''or response==''):
    count13=0
    print('Your Current score is:',count13)
elif(response=='maybe' or response=='MAYBE' or response=='Maybe'): 
    count13=0
    count13=count13+1
    print('Your Current Score is:',count13)
    
elif(response=='No'or response=='no'):

    count13=0
    count13=count13+2
    print('Your CurrentScore is:',count13)
    
elif(response=='Yes' or response=='yes' or response=='YES') :
    count13=0
    count13=count13+3
    print('Your Current Score is:',count13)
count1=count13
print(count1)
print('Now moving on to the next question.')
print('Do you have the patient have difficulty in recalling conversations of few days before than he/she used to be 5-6 years ago')
response1=input('Enter your response: ')
count2=count1
if(response1==''or response1==''):
    count2=count2+0
    print('Your Current score is:',count)
elif(response1=='Maybe' or response1=='maybe' or response1=='MAYBE'):  
    
    count2=count2+2
    print('Your Current Score is:',count)
    
elif(response1=='No'or response1=='no'):

    
    count2=count2+2
    print('Your Current Score is:',count1)
    
elif(response1=='Yes' or response1=='yes' or response1=='YES') :
    
    count2=count2+3
    print('Your Current Score is:',count2)

print(count2)
response2=input('Enter your response: ')
count3=count2
if(response2==''or response2==''):
    count3=count3+0
    print('Your score is:',count3)
elif(response2=='Maybe' or response2=='maybe' or response2=='MAYBE'):
    
    count3=count3+2
    print('Your Score is:',count3)
    
elif(response2=='No'or response2=='no'):

    
    count3=count3+2
    print('Your Score is:',count3)
    
elif(response2=='Yes' or response2=='yes' or response2=='YES') :
    
    count3=count3+3
    print('Your Score is:',count3)

print(count3)
print('Now moving to the next question')
print('Are you able to manage medications properly')
response3=input('Enter your response: ')
count4=count3
if(response3=='' or response3==''):
    count4=count4+0
    print('Your score is:',count4)
elif(response3=='Maybe' or response3=='maybe' or response3=='MAYBE'):
    
    count4=count4+2
    print('Your Score is:',count4)
    
elif(response3=='No'or response3=='no'):

    
    count4=count4+2
    print('Your Score is:',count4)
    
 
elif(response2=='Yes' or response2=='yes' or response2=='YES') :   
    count4=count4+3
    print('Your Score is:',count4)

print(count4)
print('Now moving to the next question')
print('Are you  less able to manage money and financial affairs(budget, paying bills) that you  used to do 5-6yrs?')
response4=input('Enter your response: ')
count5=count4
if(response4==''or response4==''):
    count5=count5+0
    print('Your score is:',count5)

elif(response4=='Maybe' or response4=='maybe' or response4=='MAYBE'):  
    count5=count5+2
    print('Your Score is:',count5)
    
elif(response4=='No'or response4=='no'):

    
    count5=count5+2
    print('Your Score is:',count5)
    
elif(response4=='Yes' or response4=='yes' or response4=='YES') : 
    
    count5=count5+3
    print('Your Score is:',count5)

print(count5)
print('Now moving to the last question')
print('During speaking, do you  find it difficult in finding the right word or have the habit of using wrong words more often than what he used to do few years ago?')
response5=input('Enter your response: ')
count6=count5
if(response5==''or response5==''):
    count6=count6+0
    print('Your Overall score is:',count6)

elif(response5=='Maybe' or response5=='maybe' or response5=='MAYBE'):   
    count6=count6+2
    print('Your Overall Score is:',count6)
    
elif(response5=='No'or response5=='no'):

    
    count6=count6+2
    print('Your Overall Score is:',count6)
elif(response5=='Yes' or response5=='yes' or response5=='YES') :    
 
    
    count6=count6+3
    print('Your Overall Score is:',count6)

print(count6)

if(count6>10):
    print('You already have Dementia')
    countforD4=countforD4 + 1
elif(count6>=6 and count<=10):
    print('You are on the verge of developing symptoms')
    countForSD4=countForSD4 + 1
else:
    print('You are not having Dementia')
    countForND4=countForND4 + 1
    
countforD5=countforD4
countForSD5=countForSD4
countForND5=countForND4
# Out:
# Welcome Once Again!!We will move to the Comaparision Test.In this test, patient answers for previous tests are compared to when he was well suppose 5-6 years ago. The scores are given for every question and final score is calculated on the basis of total score of all questions:
# Please wait for sometime and relax
# Enter the time in seconds: 1
# Your Time starts!!
# Your time finishes!!
# Questioning starts
# Do you have difficulty in understanding recent  things than what it used to be 5-6 years ago
# Enter your response: Yes
# Your Current Score is: 3
# 3
# Now moving on to the next question.
# Do you have the patient have difficulty in recalling conversations of few days before than he/she used to be 5-6 years ago
# Enter your response: No
# Your Current Score is: 3
# 5
# Enter your response: No
# Your Score is: 7
# 7
# Now moving to the next question
# Are you able to manage medications properly
# Enter your response: No
# Your Score is: 9
# 9
# Now moving to the next question
# ...

# %% [markdown]
# # MEMORY TEST

# %%
print('Welcome to next test Again!!Now we are going to the last test of the whole process and that is Memory Test')
print('In this test ,you have to answer 15 true/false questions which are useful in checking if your brain is functioning properly and  If any doubt is there then the patient or the family can decide whether to consider changes in the lifestyle or you should consult your doctor. ')
print('Let us start now')
print('More frequently do you forget the day of week:')

response=input('Enter your response: ')
count=0
if(response=='True'or response=='Yes' or response=='true'or response=='YES' or response=='yes'):
    count=count+1
    print('Your Current score is:',count)
else: 
    
    count=count+0
    print('Your Current Score is:',count)

print(count)
count1=count
print('Let us move to the second question now')
print('Sometimes do you forget what you were looking for:')
response1=input('Enter your response: ')

if(response1=='True'or response1=='Yes' or response1=='true'or response1=='yes'or response1=='YES'):
    count1=count1+1
    print('Your Current score is:',count1)
else: 
    
    count1=count1+0
    print('Your Current Score is:',count1)

print(count1)
count2=count1
print('Let us move to the third question now')
print('Did your family and your friends think that you are becoming more forgetful than before:')
response2=input('Enter your response: ')

if(response2=='True'or response2=='Yes' or response2=='true'or response2=='yes'or response2=='YES'):
    count2=count2+1
    print('Your Current score is:',count2)
else: 
    
    count2=count2+0
    print('Your Current Score is:',count2)

print(count2)
count3=count2
print('Let us move to the fourth question now')
print('Sometimes do you forget names of your friends:')
response3=input('Enter your response: ')

if(response3=='True'or response3=='Yes' or response3=='true'or response3=='YES' or response3=='yes'):
    count3=count3+1
    print('Your Current score is:',count3)
else: 
    
    count3=count3+0
    print('Your Current Score is:',count3)

print(count3)
count4=count3
print('Let us move to the fifth question now')
print('Do you find it hard to add two-digit numbers without writing them.:')
response4=input('Enter your response: ')

if(response4=='True'or response4=='Yes' or response4=='true'or response4=='yes'or response4=='YES'):
    count4=count4+1
    print('Your Current score is:',count4)
else: 
    
    count4=count4+0
    print('Your Current Score is:',count4)

print(count4)
count5=count4
print('Let us move to the sixth question now')
print('Do you frequently miss appointments because you forget them: ')
response5=input('Enter your response: ')

if(response5=='True'or response5=='Yes' or response5=='true'or response5=='yes'or response5=='YES'):
    count5=count5+1
    print('Your Current score is:',count5)
else: 
    
    count5=count5+0
    print('Your Current Score is:',count5)

print(count5)
count6=count5
print('Let us move to the seventh question now')
print('Do you rarely feel energetic.')
response6=input('Enter your response: ')

if(response6=='True'or response6=='Yes' or response6=='true'or response6=='YES' or response6=='yes'):
    count6=count6+1
    print('Your Current score is:',count6)
else: 
    
    count6=count6+0
    print('Your Current Score is:',count6)

print(count6)
count7=count6
print('Let us move to the eight question now')
print('Do the small problems trouble you more: ')
response7=input('Enter your response: ')

if(response7=='True'or response7=='Yes' or response7=='true'or response7=='yes'or response7=='YES'):
    count7=count7+1
    print('Your Current score is:',count7)
else: 
    
    count7=count7+0
    print('Your Current Score is:',count7)

print(count7)
count8=count7
print('Let us move to the ninth question now')
print('Sometimes it I hard for you to concentrate for even an hour.')
response8=input('Enter your response: ')

if(response8=='True'or response8=='Yes' or response8=='true'or response8=='yes'or response8=='YES'):
    count8=count8+1
    print('Your Current score is:',count8)
else: 
    
    count8=count8+0
    print('Your Current Score is:',count8)

print(count8)    
count9=count8
print('Let us move to the tenth question now')
print('Do you frequently misplace your keys and when you try to find then you can’t remember where have you placed your keys..')
response9=input('Enter your response: ')

if(response9=='True'or response9=='Yes' or response9=='true'or response9=='yes'or response9=='YES'):
    count9=count9+1
    print('Your Current score is:',count9)
else: 
    
    count9=count9+0
    print('Your Current Score is:',count9)

print(count9)    
count10=count9
print('Let us move to the eleventh question now')
print('Do you frequently repeat yourself.')
response10=input('Enter your response: ')

if(response10=='True'or response10=='Yes' or response10=='true'or response10=='yes'or response10=='YES'):
    count10=count10+1
    print('Your Current score is:',count9)
else: 
    
    count10=count10+0
    print('Your Current Score is:',count9)

print(count10)    
count11=count10
print('Let us move to the twelfth question now')
print('Sometimes do you get lost while driving even knowing the route because earlier you have been there.')
response11=input('Enter your response: ')

if(response11=='True'or response11=='Yes' or response11=='true'or response11=='yes'or response11=='YES'):
    count11=count11+1
    print('Your Current score is:',count11)
else: 
    
    count11=count11+0
    print('Your Current Score is:',count11)

print(count11) 
count12=count11
print('Let us move to the thirteenth question now')
print('Sometimes do you forget the point that you were trying to make.')
response12=input('Enter your response: ')

if(response12=='True'or response12=='Yes' or response12=='true'or response12=='yes'or response12=='YES'):
    count12=count12+1
    print('Your Current score is:',count12)
else: 
    
    count12=count12+0
    print('Your Current Score is:',count12)

print(count12) 
count13=count12
print('Let us move to the fourteenth question now')
print('Do you depend on  Caffeine so that you feel mentally sharp.')
response13=input('Enter your response: ')

if(response13=='True'or response13=='Yes' or response13=='true'or response13=='YES' or response13=='yes'):
    count13=count13+1
    print('Your Current score is:',count13)
else: 
    
    count13=count13+0
    print('Your Current Score is:',count13)

print(count13) 
count14=count13
print('Let us move to the fifrteenth question now')
print('Does it take you longer time now for learning things than it used to take')
response14=input('Enter your response: ')

if(response14=='True'or response14=='Yes' or response14=='true'or response14=='yes'or response14=='YES'):
    count14=count14+1
    print('Your Current score is:',count14)
else: 
    
    count14=count14+0
    print('Your Current Score is:',count14)

print(count14) 

if(count14>=5 and count14<=8):
    print('You are not having Dementia')
    countForND5=countForND5 + 1
elif(count14>=9 and count14<=12):
    print('You may be having the symptoms of Dementia')
    countForSD5=countForSD5 + 1
elif(count14>=13 and count14<=15):
    print('You are having  Dementia')
    countforD5=countforD5 + 1
    
   
countforD6=countforD5
countForND6=countForND5
countForSD6=countForSD5
# Out:
# Welcome to next test Again!!Now we are going to the last test of the whole process and that is Memory Test
# In this test ,you have to answer 15 true/false questions which are useful in checking if your brain is functioning properly and  If any doubt is there then the patient or the family can decide whether to consider changes in the lifestyle or you should consult your doctor.
# Let us start now
# More frequently do you forget the day of week:
# Enter your response: Yes
# Your Current score is: 1
# 1
# Let us move to the second question now
# Sometimes do you forget what you were looking for:
# Enter your response: No
# Your Current Score is: 1
# 1
# Let us move to the third question now
# Did your family and your friends think that you are becoming more forgetful than before:
# Enter your response: No
# Your Current Score is: 1
# 1
# Let us move to the fourth question now
# Sometimes do you forget names of your friends:
# Enter your response: Yes
# Your Current score is: 2
# 2
# ...

# %% [markdown]
# # IMAGE RECOGNITION TEST

# %%
print("Welcome Once Again!!Now we will move to Our Last Test which is Image Recognition Test.In this test you will be shown different images")
print("You have to recognize them and based on your recognition you will be scored ")
print("Let's start with the test")
print("Here is the image.Please take some time and recognize the image ")


from IPython.display import Image
Image(filename='dog.jpg',width=300)
# Out:
# Welcome Once Again!!Now we will move to Our Last Test which is Image Recognition Test.In this test you will be shown different images
# You have to recognize them and based on your recognition you will be scored
# Let's start with the test
# Here is the image.Please take some time and recognize the image

# %%
print("Please give your response:")
a='Dog'
b='dog'
response=input('Enter your response:')
count10=0
if(response==a or response==b):
    count10=count10+1
    print('Your Score is:',count10)
else: 
    count10=0
    print('Your Score is:',count10)
count11=count10
# Out:
# Please give your response:
# Enter your response:dog
# Your Score is: 1

# %%
from IPython.display import Image
Image(filename='Cat1.jpg',width=300)

# %%
print("Please give your response:")
c='Cat'
d='cat'
response=input('Enter your response:')
count12=count11
if(response==c or response==d):
    count12=count12+1
    print('Your Score is:',count12)
else: 
    count12=0+count11
    print('Your Score is:',count12)
# Out:
# Please give your response:
# Enter your response:cat
# Your Score is: 2

# %%
from IPython.display import Image
Image(filename='elephant.jpg',width=300)

# %%
print("Please give your response:")
response=input('Enter your response:')

e='Elephant'
f='elephant'
count13=count12
if(response==e or response==f):
    count13=count13+1
    print('Your Score is:',count13)
else: 
    count13=0+count12
    print('Your Score is:',count13)
print(count13)
# Out:
# Please give your response:
# Enter your response:elephant
# Your Score is: 3
# 3

# %%
if(count13==3):
    print("You are not having Dementia")
    countForND6=countForND6 +1
elif(count13==2):
    print("Maybe you are on the verge of developing symptoms.")
    countForSD6=countForSD6 + 1
elif(count13==1 or count13==0):
    print("You have just started showing symptoms of Dementia")
    countForSD6=countForSD6 + 1
else:
    print("You have already having symptoms of Dementia")
    countforD6=countforD6 + 1
print("Now Here comes to the end of test!!After final evaluatuon and scoring we will be submitting you the report")
countforD7=countforD6
countForSD7=countForSD6
countForND7=countForND6
# Out:
# You are not having Dementia
# Now Here comes to the end of test!!After final evaluatuon and scoring we will be submitting you the report

# %% [markdown]
# # FINAL REPORT

# %%
print(f'Hello {name} Your Virtual Dementia Report is as folllows:')
print("No of tests in which you have got the report as Having Dementia",countforD7)
print("No of tests in which you have got the report as Symptoms of Having Dementia",countForSD7)
print("No of tests in which you have got the report as Not Having Dementia",countForND7)
countforD8=countforD7
countForSD8=countForSD7
countForND8=countForND7
if(countforD8>=countForND8 and countforD7>=countForND7):
     print("You are suffering from acute Dementia.Kindly consult your doctor as soon as possible .Please don't do any delay otherwise it might result into Alzheimers which will make your life even worse than before")
elif(countForSD8>=countforD8 and countForSD8>=countForND8):
     print("You are having symptoms of Dementia. You should do some changes in your lifestyle like Exercise and physical activity can have lots of benefits for people with dementia. It can help regulate their sleep and prevent restlessness and sleeplessness in the evening. It can also help maintain a positive mood and lower the risk of them developing depression. ")
else:
     print('You are not suffering from Dementia and you are perfectly fine')
# Out:
# Hello RAVI KUMAR GUPTA Your Virtual Dementia Report is as folllows:
# No of tests in which you have got the report as Having Dementia 3
# No of tests in which you have got the report as Symptoms of Having Dementia 3
# No of tests in which you have got the report as Not Having Dementia 1
# You are suffering from acute Dementia.Kindly consult your doctor as soon as possible .Please don't do any delay otherwise it might result into Alzheimers which will make your life even worse than before
