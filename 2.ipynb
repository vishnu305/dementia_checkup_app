# %% [markdown]
# # WELCOME TO THE INTEGRATED PLATFORM FOR ALZHEIMER'S   IDENTIFICATION

# %%
from IPython.display import Image
Image(filename='aa.jpg',width=500)

# %%
print("Hello Patient,Welcome To the Virtual Dementia Detection System")
print("I am Virtual Doctor")
print("Could you tell me your name and age so that I could finalize your reports at the end of all subsequent tests\n"
      )
name = input("Enter your name:")
age = int(input("Enter your age:"))
print(
    f"OK {name} Firstly I would like to inform you regarding the First Layer of tests that we conduct for diagnosis of Dementia are as follows:\n")
print("\t 1.CLOCK DRAWING Test\n"
      "\t 2.PUZZLE  Test\n ")
print("If you are able to pass First Layer of Tests then we will not move to the next Layer of Tests.And if there is a suspection or you are not able to pass the test then we will move to the second layer of tests ")
print("So now let's start with our first test i.e. CLOCK DRAWING TEST\n")
print("Clock Drawing Test: In this test, patient is asked to use a blank page in order to : –",
     "* mark all the numbers to indicate the    hours of a clock with equal spacing \n",
      "*mark in hands to show 10 minutes past 11(10:11)\n")
print("It is basically done to screen people who have neurological problems such as Dementia. Scores are given accordingly")
# Out:
# Hello Patient,Welcome To the Virtual Dementia Detection System
# I am Virtual Doctor
# Could you tell me your name and age so that I could finalize your reports at the end of all subsequent tests
#
# Enter your name:
# Enter your age:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-58a6cee81c13> in <module>
#       4       )
#       5 name = input("Enter your name:")
# ----> 6 age = int(input("Enter your age:"))
#       7 print(
#       8     f"OK {name} Firstly I would like to inform you regarding the First Layer of tests that we conduct for diagnosis of Dementia are as follows:\n")
#
# ValueError: invalid literal for int() with base 10: ''

# %%
from PIL import ImageTk, Image, ImageDraw
import PIL
from tkinter import *

width = 100  # canvas width
height = 100 # canvas height
center = height//2
white = (155, 155, 155) # canvas back

def save():
    # save image to hard drive
    filename = "user_input.jpg"
    output_image.save(filename)

def paint(event):
    x1, y1 = (event.x - 1), (event.y - 1)
    x2, y2 = (event.x + 1), (event.y + 1)
    canvas.create_oval(x1, y1, x2, y2, fill="black",width=5)
    draw.line([x1, y1, x2, y2],fill="black",width=5)

master = Tk()

# create a tkinter canvas to draw on
canvas = Canvas(master, width=width, height=height, bg='white')
canvas.pack()

# create an empty PIL image and draw object to draw on
output_image = PIL.Image.new("RGB", (width, height), white)
draw = ImageDraw.Draw(output_image)
canvas.pack(expand=YES, fill=BOTH)
canvas.bind("<B1-Motion>", paint)

# add a button to save the image
button=Button(text="save",command=save)
button.pack()

master.mainloop()

# %%
import binascii
 
count=0
with open('Image.jpg', 'rb') as f:
     content1 = f.read()
with open('user_input.jpg', 'rb') as f:
     content2 = f.read()
if content1 == content2:
     count=count+1
     print("Score : ",count)
else:
     count=0
     print("Score :",count)
count1=count
# Out:
# Score : 0

# %%
if(count==1):
    print("You  are not having Dementia")
else:
    print("You are suspected for having Dementia")
# Out:
# You are suspected for having Dementia

# %%
print("Welcome Again !!Now we will move to Our Next  Test which is Puzzle Test.In this test you will be shown different puzzles")
print("You have to answer  and based on your answer you will be scored ")
print("Let's start with the test")
print("Here is the puzzle.Please take some time and answer it in one word  ")


from IPython.display import Image
Image(filename='burger.jpeg',width=700)
# Out:
# Welcome Again !!Now we will move to Our Next  Test which is Puzzle Test.In this test you will be shown different puzzles
# You have to answer  and based on your answer you will be scored
# Let's start with the test
# Here is the puzzle.Please take some time and answer it in one word

# %%
print("Please give your response:")
a='1'
b='first'
c='one'
count2=count1
response=input('Enter your response:')
if(response==a or response==b or response==c):
    reason=input("Please suggest the reason also: ")
    count2=count2+1
    print('Your Score is:',count2)
else: 
    count2=count2+0
    print('Your Score is:',count2)
count3=count2
# Out:
# Please give your response:
# Enter your response:1
# Please suggest the reason also: hvihbhuo
# Your Score is: 1

# %%
print("Here is the puzzle.Please take some time and answer it in one word")


from IPython.display import Image
Image(filename='Hamiltonian.jpeg',width=700)
# Out:
# Here is the puzzle.Please take some time and answer it in one word

# %%
print("Please give your response:")
a='2'
b='second'
c='two'
count4=count3
response=input('Enter your response:')
if(response==a or response==b or response==c):
     reason1=input("Please suggest the reason also: ")
     count4=count4+1
     print('Your Score is:',count4)
else: 
    count4=count4+0
    print('Your Score is:',count4)
count5=count4
# Out:
# Please give your response:
# Enter your response:2
# Please suggest the reason also: hvihhou
# Your Score is: 2

# %%
print("Here is the puzzle.Please take some time and answer it in one word")


from IPython.display import Image
Image(filename='Odd.jpeg',width=700)
# Out:
# Here is the puzzle.Please take some time and answer it in one word

# %%
print("Please give your response:")
a='2'
b='second'
c='two'
count6=count5
response=input('Enter your response:')
if(response==a or response==b or response==c):
    reason2=input("Please suggest the reason also")
    count6=count6+1
    print('Your Score is:',count6)
else: 
    count6=count6+0
    print('Your Score is:',count6)
count7=count6
# Out:
# Please give your response:
# Enter your response:2
# Please suggest the reason alsohvbhobbo
# Your Score is: 3

# %%
if(count7>2):
    print(" You have successfully passed the test and you are not having Dementia and you are perfectly fine\n")
    print("No need to go for Second Layer of Tests")
elif(count7<=2):
    print("You are suspected of having Dementia. Now you would have to go for Second Layer of Tests")
# Out:
#  You have successfully passed the test and you are not having Dementia and you are perfectly fine
#
# No need to go for Second Layer of Tests
